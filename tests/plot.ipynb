# %%
from matplotlib import pyplot as plt
import pandas as pd
import scipy.curvefit
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 3
#       1 from matplotlib import pyplot as plt
#       2 import pandas as pd
# ----> 3 import scipy.curvefit
#
# ModuleNotFoundError: No module named 'scipy'

# %%
df = pd.read_csv('/Users/cedric.kessler/GIT-2/gyroscope-ui/tests/Loooong.csv')
df.head()
# Out:
#    Time (s)  Frequency (Hz)  Accel Z  Gyro Z
# 0     0.000        7.407407    -9.47   -0.01
# 1     0.013        7.407407    -9.44   -0.01
# 2     0.025        7.407407    -9.41   -0.01
# 3     0.037        7.407407    -9.50   -0.01
# 4     0.048        7.407407    -9.48   -0.01

# %%
plotpoints = df[df["Time (s)"] < 500]

plt.figure(figsize=(10, 6))
plt.plot(plotpoints['Time (s)'], plotpoints['Frequency (Hz)'], label='Frequency (Hz)', color='blue')
plt.xlabel('Time (s)')
plt.ylabel('Frequency (Hz)')
plt.title('Frequency vs Time')
plt.legend()
plt.grid()
plt.show()
